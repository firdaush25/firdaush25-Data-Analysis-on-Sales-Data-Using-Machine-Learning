# %% [markdown]
# # Data Analysis on Sales dataset
# # Project By: Firdaush Alam
# #  Date:23-07-2025

# %% [markdown]
# ## 1. Importing Pandas Library

# %%
import pandas as pd

# %% [markdown]
# ## 2.Reading the csv file data using panda and storing into variable data.

# %%
data=pd.read_csv('sales_data.csv')

# %% [markdown]
# ## 3. Displaying the data

# %% [markdown]
# ### 3.1 Length of the data

# %%
len(data)
# Out:
# 1000

# %% [markdown]
# ### 3.2 Shape of the data

# %%
data.shape
# Out:
# (1000, 14)

# %% [markdown]
# ### 3.3 Data of Top 5 Rows

# %%
data.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold
# 0        1052  2023-02-03       Bob  North       5053.97             18  \
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount
# 0        Furniture     152.75      267.22     Returning      0.09  \
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# 1           Cash        Retail             West-Bob
# 2  Bank Transfer        Retail          South-David
# 3    Credit Card        Retail            South-Bob
# 4    Credit Card        Online         East-Charlie

# %% [markdown]
# ### 3.4 Data of 5 Rows from bottom

# %%
data.tail()
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold
# 995        1010  2023-04-15   Charlie  North       4733.88              4  \
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount
# 995             Food    4943.03     5442.15     Returning      0.29  \
# 996         Clothing    1754.32     1856.40           New      0.21
# 997         Clothing     355.72      438.27     Returning      0.06
# 998      Electronics    3685.03     3743.39           New      0.01
# 999             Food    2632.58     2926.68     Returning      0.14
#
#     Payment_Method Sales_Channel Region_and_Sales_Rep
# 995           Cash        Online        North-Charlie
# 996  Bank Transfer        Retail            North-Bob
# 997  Bank Transfer        Online          South-David
# 998  Bank Transfer        Online           West-David
# 999           Cash        Online           East-Alice

# %% [markdown]
# ### 3.5 Displaying the first n rows

# %%
data.head(10)
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold
# 0        1052  2023-02-03       Bob  North       5053.97             18  \
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
# 5        1021  2023-02-11   Charlie   West       3761.15             32
# 6        1083  2023-04-11       Bob   West        618.31             29
# 7        1087  2023-01-06       Eve  South       7698.92             46
# 8        1075  2023-06-29     David  South       4223.39             30
# 9        1075  2023-10-09   Charlie   West       8239.58             18
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount
# 0        Furniture     152.75      267.22     Returning      0.09  \
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
# 5             Food     900.79     1106.51           New      0.21
# 6        Furniture    2408.81     2624.09     Returning      0.14
# 7        Furniture    3702.51     3964.65           New      0.12
# 8        Furniture     738.06     1095.45           New      0.05
# 9         Clothing    2228.35     2682.34           New      0.13
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# 1           Cash        Retail             West-Bob
# 2  Bank Transfer        Retail          South-David
# 3    Credit Card        Retail            South-Bob
# 4    Credit Card        Online         East-Charlie
# 5           Cash        Online         West-Charlie
# 6           Cash        Online             West-Bob
# 7  Bank Transfer        Online            South-Eve
# 8  Bank Transfer        Online          South-David
# 9  Bank Transfer        Online         West-Charlie

# %% [markdown]
# ### 3.6 Information of the dataset for numerical data and categorical data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Product_ID            1000 non-null   int64
#  1   Sale_Date             1000 non-null   object
#  2   Sales_Rep             1000 non-null   object
#  3   Region                1000 non-null   object
#  4   Sales_Amount          1000 non-null   float64
#  5   Quantity_Sold         1000 non-null   int64
#  6   Product_Category      1000 non-null   object
#  7   Unit_Cost             1000 non-null   float64
#  8   Unit_Price            1000 non-null   float64
#  9   Customer_Type         1000 non-null   object
#  10  Discount              1000 non-null   float64
#  11  Payment_Method        1000 non-null   object
#  12  Sales_Channel         1000 non-null   object
#  13  Region_and_Sales_Rep  1000 non-null   object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 109.5+ KB

# %% [markdown]
# ### 3.7 Stastical summary of the dataset

# %%
data.describe()
# Out:
#         Product_ID  Sales_Amount  Quantity_Sold    Unit_Cost   Unit_Price
# count  1000.000000   1000.000000    1000.000000  1000.000000  1000.000000  \
# mean   1050.128000   5019.265230      25.355000  2475.304550  2728.440120
# std      29.573505   2846.790126      14.159006  1417.872546  1419.399839
# min    1001.000000    100.120000       1.000000    60.280000   167.120000
# 25%    1024.000000   2550.297500      13.000000  1238.380000  1509.085000
# 50%    1051.000000   5019.300000      25.000000  2467.235000  2696.400000
# 75%    1075.000000   7507.445000      38.000000  3702.865000  3957.970000
# max    1100.000000   9989.040000      49.000000  4995.300000  5442.150000
#
#          Discount
# count  1000.00000
# mean      0.15239
# std       0.08720
# min       0.00000
# 25%       0.08000
# 50%       0.15000
# 75%       0.23000
# max       0.30000

# %% [markdown]
# ### 3.8 Accessing the data using the three methods of pandas:
#     (i) By indexing
#     (ii)By slicing
#     (iii)By Filtering

# %% [markdown]
# #### 3.8.1.1 Accessing the data of column_name "Sales_Rep" using index.

# %%
data["Sales_Rep"]
# Out:
# 0          Bob
# 1          Bob
# 2        David
# 3          Bob
# 4      Charlie
#         ...
# 995    Charlie
# 996        Bob
# 997      David
# 998      David
# 999      Alice
# Name: Sales_Rep, Length: 1000, dtype: object

# %% [markdown]
# #### 3.8.1.2 Accessing the data of Multiple columns at once using index.

# %%
data[["Sales_Rep", "Region", "Customer_Type", "Sales_Amount"]].head()
# Out:
#   Sales_Rep Region Customer_Type  Sales_Amount
# 0       Bob  North     Returning       5053.97
# 1       Bob   West     Returning       4384.02
# 2     David  South     Returning       4631.23
# 3       Bob  South           New       2167.94
# 4   Charlie   East           New       3750.20

# %% [markdown]
# #### 3.8.1.3 Data of all the column values in the row with index label 10

# %%
data.loc[10]
# Out:
# Product_ID                       1088
# Sale_Date                  2023-11-16
# Sales_Rep                         Eve
# Region                          North
# Sales_Amount                  8518.45
# Quantity_Sold                      13
# Product_Category            Furniture
# Unit_Cost                     2440.11
# Unit_Price                     2517.6
# Customer_Type                     New
# Discount                         0.23
# Payment_Method          Bank Transfer
# Sales_Channel                  Retail
# Region_and_Sales_Rep        North-Eve
# Name: 10, dtype: object

# %% [markdown]
# #### 3.8.1.4 Data of all column values in the Multiple rows with index label 5,10,15,20

# %%
data.loc[[5, 10, 15, 20]]
# Out:
#     Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold
# 5         1021  2023-02-11   Charlie   West       3761.15             32  \
# 10        1088  2023-11-16       Eve  North       8518.45             13
# 15        1053  2023-10-16       Bob  North       2235.83             48
# 20        1002  2023-04-22       Eve  North       6551.23              9
#
#    Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount
# 5              Food     900.79     1106.51           New      0.21  \
# 10        Furniture    2440.11     2517.60           New      0.23
# 15        Furniture     121.19      487.65           New      0.18
# 20      Electronics    4398.16     4439.12           New      0.18
#
#    Payment_Method Sales_Channel Region_and_Sales_Rep
# 5            Cash        Online         West-Charlie
# 10  Bank Transfer        Retail            North-Eve
# 15           Cash        Retail            North-Bob
# 20  Bank Transfer        Online            North-Eve

# %% [markdown]
# #### 3.8.1.5 Data of the rows with index labels from 0 to 29 using range

# %%
data.loc[[x for x in range(30)]]
# Out:
#     Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold
# 0         1052  2023-02-03       Bob  North       5053.97             18  \
# 1         1093  2023-04-21       Bob   West       4384.02             17
# 2         1015  2023-09-21     David  South       4631.23             30
# 3         1072  2023-08-24       Bob  South       2167.94             39
# 4         1061  2023-03-24   Charlie   East       3750.20             13
# 5         1021  2023-02-11   Charlie   West       3761.15             32
# 6         1083  2023-04-11       Bob   West        618.31             29
# 7         1087  2023-01-06       Eve  South       7698.92             46
# 8         1075  2023-06-29     David  South       4223.39             30
# 9         1075  2023-10-09   Charlie   West       8239.58             18
# 10        1088  2023-11-16       Eve  North       8518.45             13
# 11        1100  2023-08-14       Bob   West       2198.74             43
# 12        1024  2023-11-11       Eve   West       6607.80             21
# 13        1003  2023-12-31     Alice  South       4775.59             30
# 14        1022  2023-08-17   Charlie  South       8813.55             21
# 15        1053  2023-10-16       Bob  North       2235.83             48
# 16        1002  2023-05-30     David  North       6810.35             17
# 17        1088  2023-10-04       Bob   East       6116.75             40
# 18        1030  2023-07-17     David   West       3023.48             19
# 19        1038  2023-03-11       Bob  South       1452.35             15
# 20        1002  2023-04-22       Eve  North       6551.23              9
# 21        1064  2023-01-04       Eve   East       7412.11             10
# 22        1060  2023-12-16       Eve   East       3224.71             44
# 23        1021  2023-11-27     Alice  South       6483.84             31
# 24        1033  2023-11-14     David  South       4011.80             23
# 25        1076  2023-12-16       Eve   East       7160.75             30
# 26        1058  2023-04-05     Alice  North       2072.23             33
# 27        1022  2023-06-01     David   East       8913.13              9
# 28        1089  2023-11-07       Bob   West       2945.36             47
# 29        1049  2023-05-17     Alice   West       3741.08              1
#
#    Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount
# 0         Furniture     152.75      267.22     Returning      0.09  \
# 1         Furniture    3816.39     4209.44     Returning      0.11
# 2              Food     261.56      371.40     Returning      0.20
# 3          Clothing    4330.03     4467.75           New      0.02
# 4       Electronics     637.37      692.71           New      0.08
# 5              Food     900.79     1106.51           New      0.21
# 6         Furniture    2408.81     2624.09     Returning      0.14
# 7         Furniture    3702.51     3964.65           New      0.12
# 8         Furniture     738.06     1095.45           New      0.05
# 9          Clothing    2228.35     2682.34           New      0.13
# 10        Furniture    2440.11     2517.60           New      0.23
# 11             Food    1100.81     1137.44     Returning      0.08
# 12             Food     622.01      641.09     Returning      0.00
# 13        Furniture    4190.28     4270.65           New      0.20
# 14             Food    2537.20     2869.60           New      0.29
# 15        Furniture     121.19      487.65           New      0.18
# 16        Furniture    4024.76     4420.15     Returning      0.04
# 17      Electronics    4904.93     5034.35           New      0.10
# 18         Clothing    3049.33     3209.22     Returning      0.26
# 19         Clothing    2543.36     2790.10     Returning      0.07
# 20      Electronics    4398.16     4439.12           New      0.18
# 21      Electronics    4764.96     5074.42           New      0.12
# 22         Clothing    3784.96     4276.99           New      0.06
# 23        Furniture    2254.99     2441.79     Returning      0.24
# 24        Furniture    2981.50     3360.40     Returning      0.22
# 25         Clothing    3519.63     3774.65           New      0.20
# 26        Furniture    1011.65     1084.28     Returning      0.07
# 27      Electronics    2263.65     2558.95           New      0.03
# 28        Furniture    4157.62     4314.56           New      0.17
# 29        Furniture    3290.89     3317.75     Returning      0.17
#
#    Payment_Method Sales_Channel Region_and_Sales_Rep
# 0            Cash        Online            North-Bob
# 1            Cash        Retail             West-Bob
# 2   Bank Transfer        Retail          South-David
# 3     Credit Card        Retail            South-Bob
# 4     Credit Card        Online         East-Charlie
# 5            Cash        Online         West-Charlie
# 6            Cash        Online             West-Bob
# 7   Bank Transfer        Online            South-Eve
# 8   Bank Transfer        Online          South-David
# 9   Bank Transfer        Online         West-Charlie
# 10  Bank Transfer        Retail            North-Eve
# 11  Bank Transfer        Online             West-Bob
# 12  Bank Transfer        Retail             West-Eve
# 13           Cash        Online          South-Alice
# 14  Bank Transfer        Retail        South-Charlie
# 15           Cash        Retail            North-Bob
# 16           Cash        Online          North-David
# 17    Credit Card        Retail             East-Bob
# 18           Cash        Online           West-David
# 19           Cash        Online            South-Bob
# 20  Bank Transfer        Online            North-Eve
# 21           Cash        Online             East-Eve
# 22  Bank Transfer        Retail             East-Eve
# 23  Bank Transfer        Online          South-Alice
# 24  Bank Transfer        Retail          South-David
# 25    Credit Card        Retail             East-Eve
# 26  Bank Transfer        Retail          North-Alice
# 27           Cash        Online           East-David
# 28  Bank Transfer        Retail             West-Bob
# 29  Bank Transfer        Online           West-Alice

# %% [markdown]
# #### 3.8.2.1 Accessing the data using "slice method" with "iloc Function"

# %% [markdown]
# [:5,:5]-->>Data of 5 rows and 5 columns

# %%
data.iloc[:5,:5]
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount
# 0        1052  2023-02-03       Bob  North       5053.97
# 1        1093  2023-04-21       Bob   West       4384.02
# 2        1015  2023-09-21     David  South       4631.23
# 3        1072  2023-08-24       Bob  South       2167.94
# 4        1061  2023-03-24   Charlie   East       3750.20

# %% [markdown]
# #### 3.8.2.2 Accessing the data using "slice method" with "iloc Function" and providing the "range"

# %%
data.iloc[8:12,:5]
# Out:
#     Product_ID   Sale_Date Sales_Rep Region  Sales_Amount
# 8         1075  2023-06-29     David  South       4223.39
# 9         1075  2023-10-09   Charlie   West       8239.58
# 10        1088  2023-11-16       Eve  North       8518.45
# 11        1100  2023-08-14       Bob   West       2198.74

# %%
data.iloc[8:13,3:7]
# Out:
#    Region  Sales_Amount  Quantity_Sold Product_Category
# 8   South       4223.39             30        Furniture
# 9    West       8239.58             18         Clothing
# 10  North       8518.45             13        Furniture
# 11   West       2198.74             43             Food
# 12   West       6607.80             21             Food

# %% [markdown]
# #### 3.8.3.1 Accessing the data using "Filter Method"

# %%
data[data["Region"]=="West"]
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold
# 1          1093  2023-04-21       Bob   West       4384.02             17  \
# 5          1021  2023-02-11   Charlie   West       3761.15             32
# 6          1083  2023-04-11       Bob   West        618.31             29
# 9          1075  2023-10-09   Charlie   West       8239.58             18
# 11         1100  2023-08-14       Bob   West       2198.74             43
# ..          ...         ...       ...    ...           ...            ...
# 980        1089  2023-11-28     David   West       8719.62              8
# 983        1039  2023-08-01       Eve   West       7527.63             36
# 989        1025  2023-12-30     David   West       9215.32             28
# 992        1084  2023-02-19     David   West       2154.66             35
# 998        1100  2023-12-20     David   West       1629.47             39
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount
# 1          Furniture    3816.39     4209.44     Returning      0.11  \
# 5               Food     900.79     1106.51           New      0.21
# 6          Furniture    2408.81     2624.09     Returning      0.14
# 9           Clothing    2228.35     2682.34           New      0.13
# 11              Food    1100.81     1137.44     Returning      0.08
# ..               ...        ...         ...           ...       ...
# 980        Furniture    4349.34     4629.98     Returning      0.01
# 983         Clothing    2919.00     3125.01           New      0.24
# 989      Electronics    2097.84     2270.99           New      0.13
# 992             Food     465.61      812.91           New      0.16
# 998      Electronics    3685.03     3743.39           New      0.01
#
#     Payment_Method Sales_Channel Region_and_Sales_Rep
# 1             Cash        Retail             West-Bob
# 5             Cash        Online         West-Charlie
# 6             Cash        Online             West-Bob
# 9    Bank Transfer        Online         West-Charlie
# 11   Bank Transfer        Online             West-Bob
# ..             ...           ...                  ...
# 980    Credit Card        Online           West-David
# 983           Cash        Online             West-Eve
# 989    Credit Card        Retail           West-David
# 992  Bank Transfer        Online           West-David
# 998  Bank Transfer        Online           West-David
#
# [244 rows x 14 columns]

# %%
data[data["Quantity_Sold"]>30]
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold
# 3          1072  2023-08-24       Bob  South       2167.94             39  \
# 5          1021  2023-02-11   Charlie   West       3761.15             32
# 7          1087  2023-01-06       Eve  South       7698.92             46
# 11         1100  2023-08-14       Bob   West       2198.74             43
# 15         1053  2023-10-16       Bob  North       2235.83             48
# ..          ...         ...       ...    ...           ...            ...
# 993        1025  2023-06-26     David  North       2457.65             47
# 994        1068  2023-04-06     Alice  South       9093.50             31
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount
# 3           Clothing    4330.03     4467.75           New      0.02  \
# 5               Food     900.79     1106.51           New      0.21
# 7          Furniture    3702.51     3964.65           New      0.12
# 11              Food    1100.81     1137.44     Returning      0.08
# 15         Furniture     121.19      487.65           New      0.18
# ..               ...        ...         ...           ...       ...
# 993        Furniture    3861.61     3998.91           New      0.25
# 994         Clothing    3169.37     3304.15     Returning      0.25
# 996         Clothing    1754.32     1856.40           New      0.21
# 998      Electronics    3685.03     3743.39           New      0.01
# 999             Food    2632.58     2926.68     Returning      0.14
#
#     Payment_Method Sales_Channel Region_and_Sales_Rep
# 3      Credit Card        Retail            South-Bob
# 5             Cash        Online         West-Charlie
# 7    Bank Transfer        Online            South-Eve
# 11   Bank Transfer        Online             West-Bob
# 15            Cash        Retail            North-Bob
# ..             ...           ...                  ...
# 993    Credit Card        Online          North-David
# 994    Credit Card        Retail          South-Alice
# 996  Bank Transfer        Retail            North-Bob
# 998  Bank Transfer        Online           West-David
# 999           Cash        Online           East-Alice
#
# [393 rows x 14 columns]

# %% [markdown]
# ## 4. Cleaning the data

# %% [markdown]
# ### 4.1Checking missing values

# %%
print(data.isnull().sum())
# Out:
# Product_ID              0
# Sale_Date               0
# Sales_Rep               0
# Region                  0
# Sales_Amount            0
# Quantity_Sold           0
# Product_Category        0
# Unit_Cost               0
# Unit_Price              0
# Customer_Type           0
# Discount                0
# Payment_Method          0
# Sales_Channel           0
# Region_and_Sales_Rep    0
# dtype: int64

# %% [markdown]
# ### 4.2 Check Missing Values Row-by-Row

# %%
missing=data.isnull().sum(axis=1)
print(missing)
print("Rows with missing values are: ",(missing>0).sum())
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Length: 1000, dtype: int64
# Rows with missing values are:  0

# %%
data[missing>0]
# Out:
# Empty DataFrame
# Columns: [Product_ID, Sale_Date, Sales_Rep, Region, Sales_Amount, Quantity_Sold, Product_Category, Unit_Cost, Unit_Price, Customer_Type, Discount, Payment_Method, Sales_Channel, Region_and_Sales_Rep]
# Index: []

# %% [markdown]
# ### 4.3 Checking the percentage of Missing Values

# %%
data.isnull().sum(axis=1).sort_values(ascending=False)/data.shape[1]*100
# Out:
# 0      0.0
# 671    0.0
# 658    0.0
# 659    0.0
# 660    0.0
#       ...
# 338    0.0
# 339    0.0
# 340    0.0
# 341    0.0
# 999    0.0
# Length: 1000, dtype: float64

# %% [markdown]
# ### 4.4 Checking Missing Values column wise

# %%
data.isnull().sum(axis=0)
# Out:
# Product_ID              0
# Sale_Date               0
# Sales_Rep               0
# Region                  0
# Sales_Amount            0
# Quantity_Sold           0
# Product_Category        0
# Unit_Cost               0
# Unit_Price              0
# Customer_Type           0
# Discount                0
# Payment_Method          0
# Sales_Channel           0
# Region_and_Sales_Rep    0
# dtype: int64

# %% [markdown]
# ### 4.5 Checking Missing Values percentage

# %%
data.isnull().sum(axis=0)/data.shape[0]*100
# Out:
# Product_ID              0.0
# Sale_Date               0.0
# Sales_Rep               0.0
# Region                  0.0
# Sales_Amount            0.0
# Quantity_Sold           0.0
# Product_Category        0.0
# Unit_Cost               0.0
# Unit_Price              0.0
# Customer_Type           0.0
# Discount                0.0
# Payment_Method          0.0
# Sales_Channel           0.0
# Region_and_Sales_Rep    0.0
# dtype: float64

# %% [markdown]
# # 5. Data Visualization

# %% [markdown]
# ### Using Matplot Library which includes:
#         (i) Line plot
#         (ii) Scatter Plot
#         (iii) Bar Graph
#         (iv) Pie Plot
#         (v) Area Plot
#         (vi) Histogram

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 5.1 Line Plot — Trends over Time
# ### Use Case: Total sales amount over time.

# %%
data['Sale_Date'] = pd.to_datetime(data['Sale_Date'])
daily_sales = data.groupby('Sale_Date')['Sales_Amount'].sum()

plt.plot(daily_sales.index, daily_sales.values, marker='o')
plt.title('Daily Sales Amount Over Time')
plt.xlabel('Date')
plt.ylabel('Sales Amount')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 5.2 Scatter Plot — Relationship Between Variables
# ### Use Case: Correlation between Unit Price and Quantity Sold.

# %%
plt.scatter(data['Unit_Price'], data['Quantity_Sold'], alpha=1)
plt.title('Unit Price vs Quantity Sold',color='red')
plt.xlabel('Unit Price')
plt.ylabel('Quantity Sold')
plt.show()

# %% [markdown]
# ## 5.3 Bar Graph — Category-wise Comparisons
# ### Use Case:  Total sales across regions or product categories.

# %%
region_sales = data.groupby('Region')['Sales_Amount'].sum()

plt.bar(region_sales.index, region_sales.values, color='skyblue')
plt.title('Sales by Region',color='red')
plt.xlabel('Region')
plt.ylabel('Total Sales Amount')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ## 5.4 Pie Plot — Proportional Breakdown
# ### Use Case: Proportion of customer types in total sales.

# %%
customer_counts = data['Customer_Type'].value_counts()

plt.pie(customer_counts.values, labels=customer_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Customer Type Distribution',color="red")
plt.axis('equal')
plt.show()

# %% [markdown]
# ## 5.5 Area Plot — Cumulative Distribution Over Time
# ### Use Case: Growth of cumulative quantity sold.

# %%
data['Sale_Date'] = pd.to_datetime(data['Sale_Date'])
daily_quantity = data.groupby('Sale_Date')['Quantity_Sold'].sum().cumsum()

plt.fill_between(daily_quantity.index, daily_quantity.values, color='lightgreen', alpha=0.7)
plt.title('Cumulative Quantity Sold Over Time',color="red")
plt.xlabel('Date')
plt.ylabel('Cumulative Quantity')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 5.6 Histogram — Distribution of Numerical Values
# ### Use Case: Distribution of discounts offered

# %%
plt.hist(data['Discount'], bins=15, color='coral', edgecolor='black')
plt.title('Discount Distribution',color='red')
plt.xlabel('Discount (%)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 6. Data Analysis
# ## Types of Data Analysis:
#  1. Univariate Analysis:- Analyzing one variable at a time
# 2. Bivariate Analysis:- Exploring relationship between two variables
# 3. Multivariate Analysis:- Studying interactions between three or more variables

# %% [markdown]
# ## 6.1 Univariate Analysis:

# %% [markdown]
# ### 6.1.1 Analyzing Numerical Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Product_ID            1000 non-null   int64
#  1   Sale_Date             1000 non-null   datetime64[ns]
#  2   Sales_Rep             1000 non-null   object
#  3   Region                1000 non-null   object
#  4   Sales_Amount          1000 non-null   float64
#  5   Quantity_Sold         1000 non-null   int64
#  6   Product_Category      1000 non-null   object
#  7   Unit_Cost             1000 non-null   float64
#  8   Unit_Price            1000 non-null   float64
#  9   Customer_Type         1000 non-null   object
#  10  Discount              1000 non-null   float64
#  11  Payment_Method        1000 non-null   object
#  12  Sales_Channel         1000 non-null   object
#  13  Region_and_Sales_Rep  1000 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 109.5+ KB

# %% [markdown]
# ### 6.1.2 Checking for any available Outliers

# %%
cols = ["Sales_Amount", "Quantity_Sold", "Unit_Cost", "Unit_Price", "Discount"]

# Creating boxplot
sns.boxplot(data=data[cols])
plt.title("Sales Metrics Boxplot with Outliers")
plt.xticks(rotation=30)
plt.ylabel("Value")
plt.show()

# %% [markdown]
# #### Sales Metrics By Customer Type

# %%
# Melting the dataset to a long format
melted = data.melt(id_vars='Customer_Type', value_vars=["Sales_Amount", "Quantity_Sold", "Unit_Cost", "Unit_Price", "Discount"],
                   var_name='Feature', value_name='Value')

# Creating boxplot colored by Customer_Type
plt.figure(figsize=(12,6))
sns.boxplot(x='Feature', y='Value', hue='Customer_Type', data=melted, palette='Set2')
plt.title("Sales Metrics by Customer Type")
plt.xticks(rotation=45)
plt.ylabel("Value")
plt.legend(title='Customer Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Sales Metrics By Region

# %%
# Melt for region grouping
melted_region = data.melt(id_vars='Region', value_vars=["Sales_Amount", "Quantity_Sold", "Unit_Cost", "Unit_Price", "Discount"],
                          var_name='Feature', value_name='Value')

# Boxplot by Region
plt.figure(figsize=(12,6))
sns.boxplot(x='Feature', y='Value', hue='Region', data=melted_region, palette='tab10')
plt.title("Sales Metrics by Region")
plt.xticks(rotation=45)
plt.ylabel("Value")
plt.legend(title='Region', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.1.3 Finding Mean() And Median() of Numerical Data

# %%
numeric_means = data.mean(numeric_only=True)
print("Mean of Numerical data:\n")
print(numeric_means)
# Out:
# Mean of Numerical data:
#
# Product_ID       1050.12800
# Sales_Amount     5019.26523
# Quantity_Sold      25.35500
# Unit_Cost        2475.30455
# Unit_Price       2728.44012
# Discount            0.15239
# dtype: float64

# %%
numeric_medians = data.median(numeric_only=True)
print("\nMedian of Numeric Features:\n")
print(numeric_medians)
# Out:
# Median of Numeric Features:
#
# Product_ID       1051.000
# Sales_Amount     5019.300
# Quantity_Sold      25.000
# Unit_Cost        2467.235
# Unit_Price       2696.400
# Discount            0.150
# dtype: float64

# %%
sns.barplot(x=numeric_means.index, y=numeric_means.values, palette="mako")
plt.title("Mean of Numeric Features")
plt.ylabel("Mean Value")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.distplot(data["Discount"], bins=50, color='purple')
plt.title('Discount Distribution', color="red")
# Out:
# C:\Users\Firdaush Alam\AppData\Local\Temp\ipykernel_15084\2938313584.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Discount"], bins=50, color='purple')
# Text(0.5, 1.0, 'Discount Distribution')

# %%
sns.histplot(data['Discount'], bins=50,kde=True, color='purple')
plt.title('Discount Distribution', color="red")
# Out:
# Text(0.5, 1.0, 'Discount Distribution')

# %%
sns.kdeplot(data['Discount'], color='purple', fill=True)
plt.title('KDE Plot of Discount')
plt.xlabel('Discount')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### 6.1.4 Analyzing Categorical Data:

# %%
pd.crosstab(data['Region'], data['Sales_Channel'])
# Out:
# Sales_Channel  Online  Retail
# Region
# East              121     142
# North             130     137
# South             112     114
# West              125     119

# %%
# Example: Total Sales by Region
region_sales = data.groupby('Region')['Sales_Amount'].sum().sort_values()
sns.barplot(x=region_sales.index, y=region_sales.values, palette='viridis')
plt.title("Total Sales by Region")
plt.ylabel("Sales Amount")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
data.groupby('Customer_Type')['Unit_Price'].mean()
data.groupby('Region')['Discount'].median()
# Out:
# Region
# East     0.17
# North    0.15
# South    0.15
# West     0.15
# Name: Discount, dtype: float64

# %%
# Pie chart for Customer Type
customer_counts = data['Customer_Type'].value_counts()
plt.pie(customer_counts, labels=customer_counts.index, autopct='%1.1f%%')
plt.title('Customer Type Distribution')
plt.show()

# %%
# Histogram of Discount
plt.hist(data['Discount'], bins=40, color='coral')
plt.title('Discount Distribution')
plt.xlabel('Discount (%)')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar chart for Product Category counts
product_counts = data['Product_Category'].value_counts()
plt.bar(product_counts.index, product_counts.values, color='teal')
plt.title('Top Product Categories')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 6.2 Bivariate Analysis:

# %% [markdown]
# ### 6.2.1 Scatter Plot: "Quantity vs Unit Price"

# %%
plt.scatter(data['Unit_Price'], data['Quantity_Sold'], alpha=1)
plt.title('Unit Price vs Quantity Sold')
plt.xlabel('Unit Price')
plt.ylabel('Quantity Sold')
plt.show()

# %% [markdown]
# ### 6.2.2 Bar Graph: Sales Amount by "Region"

# %%
region_sales = data.groupby('Region')['Sales_Amount'].sum()
plt.bar(region_sales.index, region_sales.values, color='skyblue')
plt.title('Total Sales by Region')
plt.xticks(rotation=30)
plt.ylabel('Sales Amount')
plt.show()

# %% [markdown]
# ### 6.2.3 Scatter Plot: Discount Vs Unit Cost

# %%
plt.scatter(data['Discount'], data['Unit_Cost'], c='darkorange')
plt.title('Discount vs Unit Cost')
plt.xlabel('Discount')
plt.ylabel('Unit Cost')
plt.show()

# %% [markdown]
# ## 6.3 Multivariate Analysis:

# %% [markdown]
# ### Visualize the correlation between different features

# %%
import seaborn as sns

# %%
pd.crosstab(data['Region'], data['Sales_Channel'])
# Out:
# Sales_Channel  Online  Retail
# Region
# East              121     142
# North             130     137
# South             112     114
# West              125     119

# %%
cross = pd.crosstab(data['Region'], data['Sales_Channel'])
sns.heatmap(cross, annot=True, cmap='Blues')
plt.title('Region vs Sales Channel')
plt.show()

# %% [markdown]
# # Heatmap()

# %%
# Select relevant numerical columns
numeric_cols = ["Sales_Amount", "Quantity_Sold", "Unit_Cost", "Unit_Price", "Discount"]

# Compute the correlation matrix
corr_matrix = data[numeric_cols].corr()

# Create heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5, linecolor='white')
plt.title("Correlation Between Sales Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# # -------------The End--------------
# ## Project By: Firdaush Alam
